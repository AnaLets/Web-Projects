# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('espessura-vida-serie.xlsx')

# %%
df
# Out:
#               Data Modelo Executante            Cor      PJI     Camada  \
# 0       07/05/2019    H79       JEAN  BLANC GLACIER  1922241     E-Coat
# 1       07/05/2019    H79       JEAN  BLANC GLACIER  1922241     E-Coat
# 2       07/05/2019    H79       JEAN  BLANC GLACIER  1922241     E-Coat
# 3       07/05/2019    H79       JEAN  BLANC GLACIER  1922241     E-Coat
# 4       07/05/2019    H79       JEAN  BLANC GLACIER  1922241     E-Coat
# ...            ...    ...        ...            ...      ...        ...
# 154591  26/08/2019    BBB       JEAN  BLANC GLACIER  3531026  ClearCoat
# 154592  26/08/2019    BBB       JEAN  BLANC GLACIER  3531026  ClearCoat
# 154593  26/08/2019    BBB       JEAN  BLANC GLACIER  3531026  ClearCoat
# 154594  26/08/2019    BBB       JEAN  BLANC GLACIER  3531026  ClearCoat
# 154595  26/08/2019    BBB       JEAN  BLANC GLACIER  3531026  ClearCoat
#
#         Ponto  Espessura de Camada          Regiao Lado  Ponto Oposto  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154596 entries, 0 to 154595
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Data                 154596 non-null  object
#  1   Modelo               154596 non-null  object
#  2   Executante           154596 non-null  object
#  3   Cor                  154596 non-null  object
#  4   PJI                  154596 non-null  int64
#  5   Camada               154596 non-null  object
#  6   Ponto                154596 non-null  int64
#  7   Espessura de Camada  154596 non-null  float64
#  8   Regiao               154596 non-null  object
#  9   Lado                 154596 non-null  object
#  10  Ponto Oposto         137904 non-null  float64
#  11  Espessura Oposta     131964 non-null  float64
#  12  Diff Lados           131964 non-null  float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 15.3+ MB

# %%
df.describe()
# Out:
#                 PJI          Ponto  Espessura de Camada   Ponto Oposto  \
# count  1.545960e+05  154596.000000        154596.000000  137904.000000
# mean   3.200400e+06      38.829698            29.184909      42.888966
# std    1.032489e+06      22.432920            11.255974      24.421981
# min    1.031382e+06       1.000000             8.073000       1.000000
# 25%    2.241157e+06      19.000000            19.362000      21.000000
# 50%    3.212529e+06      39.000000            26.659000      43.000000
# 75%    4.040487e+06      58.000000            38.914000      62.000000
# max    5.206815e+06      82.000000            60.990000      97.000000
#
#        Espessura Oposta     Diff Lados
# count     131964.000000  131964.000000
# mean          29.298944       2.370342
# std           11.268385       2.388156
# min            8.073000       0.000000
# 25%           19.475000       0.643000
# 50%           26.751000       1.579000
# 75%           38.993250       3.316250
# ...

# %%
df = df.loc[(df['Modelo'] == 'L52') & (df['Cor'] == 'ROUGE VIF')]

# %%
df = df.drop('Executante', axis = 1)

# %%
df.describe()
# Out:
#                 PJI          Ponto  Espessura de Camada   Ponto Oposto  \
# count  1.319640e+05  131964.000000        131964.000000  131964.000000
# mean   3.207826e+06      40.807402            29.304906      40.768391
# std    1.036313e+06      22.776997            11.270833      22.760489
# min    1.031382e+06       1.000000             8.073000       1.000000
# 25%    2.250040e+06      20.000000            19.477000      20.000000
# 50%    3.231482e+06      42.000000            26.752500      41.000000
# 75%    4.111008e+06      60.000000            38.994000      60.000000
# max    5.206815e+06      82.000000            60.990000      82.000000
#
#        Espessura Oposta     Diff Lados
# count     131964.000000  131964.000000
# mean          29.298944       2.370342
# std           11.268385       2.388156
# min            8.073000       0.000000
# 25%           19.475000       0.643000
# 50%           26.751000       1.579000
# 75%           38.993250       3.316250
# ...

# %%
df.isna().sum()
# Out:
# Data                    0
# Modelo                  0
# Cor                     0
# PJI                     0
# Camada                  0
# Ponto                   0
# Espessura de Camada     0
# Regiao                  0
# Lado                    0
# Ponto Oposto           84
# Espessura Oposta       84
# Diff Lados             84
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Data                   0
# Modelo                 0
# Cor                    0
# PJI                    0
# Camada                 0
# Ponto                  0
# Espessura de Camada    0
# Regiao                 0
# Lado                   0
# Ponto Oposto           0
# Espessura Oposta       0
# Diff Lados             0
# dtype: int64

# %%
df['Diff Lados'].min()
# Out:
# 0.0109999999999992

# %%
df['Diff Lados'].max()
# Out:
# 12.734

# %%
df.columns
# Out:
# Index(['Data', 'Modelo', 'Cor', 'PJI', 'Camada', 'Ponto',
#        'Espessura de Camada', 'Regiao', 'Lado', 'Ponto Oposto',
#        'Espessura Oposta', 'Diff Lados'],
#       dtype='object')

# %%
y_pos = df['Ponto']

# Create bars
plt.bar(df['Regiao'], y_pos)
plt.xticks(rotation='vertical')


# Show graphic
plt.show()

# %%
y_pos = df['Diff Lados']

# Create bars
plt.bar(df['Regiao'], y_pos)
plt.xticks(rotation='vertical')


# Show graphic
plt.show()

# %%
df1 = df.loc[(df['Regiao'] == 'paralama-Diant')]

y_pos = df1['Data']

# Create bars
plt.bar(y_pos, df1['Diff Lados'])
plt.xticks(rotation='vertical')


# Show graphic
plt.show()

# %%
df2 = df.loc[(df['Regiao'] == 'porta-Diant')]

y_pos = df2['Data']

# Create bars
plt.bar(y_pos, df2['Diff Lados'])
plt.xticks(rotation='vertical')


# Show graphic
plt.show()

# %%
df1.plot(x='Data', y='Diff Lados', rot = 45);

# %%
df2.plot(x='Data', y='Diff Lados', rot = 45);

# %%
y_pos = df['Diff Lados']

# Create bars
plt.bar(df['Camada'], y_pos)
plt.xticks(rotation='vertical')


# Show graphic
plt.show()

# %%
df5 = df.loc[(df['Regiao'] == 'custodia')]

y_pos = df5['Data']

# Create bars
plt.bar(y_pos, df5['Diff Lados'])
plt.xticks(rotation='vertical')


# Show graphic
plt.show()

# %%
df5.plot(x='Data', y='Diff Lados', rot = 45);

# %%
df3 = df.loc[(df['Camada'] == 'ClearCoat')]

y_pos = df3['Data']

# Create bars
plt.bar(y_pos, df3['Diff Lados'])
plt.xticks(rotation='vertical')


# Show graphic
plt.show()

# %%
df3.plot(x='Data', y='Diff Lados', rot = 45);

# %%
df4 = df.loc[(df['Camada'] == 'Medium Prime')]

y_pos = df4['Data']

# Create bars
plt.bar(y_pos, df4['Diff Lados'])
plt.xticks(rotation='vertical')


# Show graphic
plt.show()

# %%
df4.plot(x='Data', y='Diff Lados', rot = 45);
